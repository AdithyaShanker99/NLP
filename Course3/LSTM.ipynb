# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import pandas as pd
import tensorflow as tf
import ast
from sklearn.model_selection import train_test_split
tf.keras.utils.set_random_seed(33)

# %%
data = pd.read_csv("data/NER_Dataset.csv", encoding = "ISO-8859-1") 
print('ORIGINAL DATA:\n', data.head())
# Out:
# ORIGINAL DATA:
#         Sentence_ID                                               Word  \
# 0      Sentence: 1  ['Thousands', 'of', 'demonstrators', 'have', '...
# 1     Sentence: 10  ['Iranian', 'officials', 'say', 'they', 'expec...
# 2    Sentence: 100  ['Helicopter', 'gunships', 'Saturday', 'pounde...
# 3   Sentence: 1000  ['They', 'left', 'after', 'a', 'tense', 'hour-...
# 4  Sentence: 10000  ['U.N.', 'relief', 'coordinator', 'Jan', 'Egel...
#
#                                                  POS  \
# 0  ['NNS', 'IN', 'NNS', 'VBP', 'VBN', 'IN', 'NNP'...
# 1  ['JJ', 'NNS', 'VBP', 'PRP', 'VBP', 'TO', 'VB',...
# 2  ['NN', 'NNS', 'NNP', 'VBD', 'JJ', 'NNS', 'IN',...
# 3  ['PRP', 'VBD', 'IN', 'DT', 'NN', 'JJ', 'NN', '...
# 4  ['NNP', 'NN', 'NN', 'NNP', 'NNP', 'VBD', 'NNP'...
#
#                                                  Tag
# 0  ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', '...
# 1  ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', '...
# 2  ['O', 'O', 'B-tim', 'O', 'O', 'O', 'O', 'O', '...
# 3  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4  ['B-geo', 'O', 'O', 'B-per', 'I-per', 'O', 'B-...

# %%
sentences = []
tags = []
for index, row in data.iterrows():
    # Convert the string representation of lists into actual lists
    words = ast.literal_eval(row['Word'])
    ner_tags = ast.literal_eval(row['Tag'])
    
    # Combine words into a sentence
    sentence = ' '.join(words)
    
    # Append to the lists
    sentences.append(sentence)
    tags.append(ner_tags)

# %%
print(sentences[0])
print(tags[0])
print(len(sentences))
print(len(tags))
# Out:
# Thousands of demonstrators have marched through London to protest the war in Iraq and demand the withdrawal of British troops from that country .
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O']
# 47959
# 47959

# %%
X_train, X_test, Y_train, Y_test = train_test_split(sentences, tags, test_size=0.2, random_state=42)

# %%
def get_sentence_vectorizer(sentences):
    sentence_vectorizer = tf.keras.layers.TextVectorization(standardize=None)
    sentence_vectorizer.adapt(sentences)
    vocab = sentence_vectorizer.get_vocabulary()
    return sentence_vectorizer, vocab

    ### END CODE HERE ###

# %%
test_vectorizer, test_vocab = get_sentence_vectorizer(X_train[:1000])
print(test_vocab)
print(f"Test vocab size: {len(test_vocab)}")
#print(test_vocab)

sentence = "I like learning new NLP models !"
sentence_vectorized = test_vectorizer(sentence)
print(f"Sentence: {sentence}\nSentence vectorized: {sentence_vectorized}")

# Check if words in the test sentence exist in the vocabulary
for word in sentence.split():
    if word in test_vocab:
        print(f"'{word}' is in the vocabulary.")
    else:
        print(f"'{word}' is NOT in the vocabulary.")
# Out:
# ['', '[UNK]', 'the', '.', ',', 'of', 'in', 'to', 'and', 'a', "'s", 'The', 'for', 'on', 'that', 'is', 'has', 'was', 'with', 'have', 'said', 'U.S.', 'by', 'says', 'say', 'as', 'at', 'are', 'from', 'will', 'an', 'were', '"', 'two', 'it', 'he', 'government', 'A', 'not', 'Mr.', 'be', 'officials', 'its', 'President', 'after', 'people', 'killed', 'his', 'also', 'more', 'who', 'their', 'been', 'which', 'military', 'United', 'Iraq', 'country', 'they', 'this', 'than', 'Friday', 'other', 'week', '-', 'would', 'had', '$', 'In', 'year', 'Sunday', 'new', 'States', 'police', 'last', 'during', 'one', 'oil', 'least', 'about', 'Thursday', 'Minister', 'Bush', 'report', 'but', 'Wednesday', 'security', 'world', 'million', 'forces', 'Tuesday', 'He', 'when', 'over', 'members', 'troops', 'group', 'four', 'Israeli', 'Iraqi', 'Iran', 'out', 'into', 'first', 'between', 'state', 'economy', 'years', 'international', 'all', 'China', 'three', 'region', 'month', 'could', 'Israel', ')', '(', 'violence', 'talks', 'soldiers', 'saying', 'leader', 'held', 'attacks', 'Saturday', 'Palestinian', 'But', 'since', 'or', 'militants', 'late', 'elections', 'city', 'because', 'authorities', 'It', 'Afghanistan', 'where', 'told', 'through', 'southern', 'official', 'next', 'leaders', 'former', 'border', 'Prime', 'European', 'Baghdad', 'up', 'until', 'rebels', 'percent', 'foreign', 'earlier', 'attack', 'arrested', 'Monday', 'British', 'Afghan', 'while', 'statement', 'reported', 'nuclear', 'near', 'meeting', 'killing', 'found', 'economic', 'capital', 'back', 'agency', 'against', 'South', 'New', 'time', 'them', 'several', 'rights', 'reports', 'president', 'no', 'minister', 'made', 'including', 'flu', 'election', 'began', 'area', 'Russia', 'International', 'Chinese', 'recent', 'province', 'power', 'if', 'human', 'groups', 'expected', 'day', 'countries', 'areas', 'any', 'announced', 'al-Qaida', 'Officials', 'November', 'North', 'Meanwhile', 'Korea', 'American', '10', "'", 'wounded', 'work', 'war', 'some', 'set', 'released', 'program', 'political', 'men', 'meet', 'investigation', 'her', 'following', 'five', 'charges', 'bird', 'billion', 'around', 'U.N.', 'Police', 'Pakistani', 'Lebanon', 'Gaza', 'what', 'there', 'suspected', 'such', 'six', 'northern', 'nations', 'militant', 'global', 'fighting', 'employees', 'did', 'being', 'another', 'aid', 'accused', 'World', 'Syria', 'Sudan', 'On', 'Indian', 'trade', 'top', 'those', 'spokesman', 'plan', 'peace', 'parliament', 'others', 'number', 'news', 'national', 'later', 'judge', 'insurgents', 'end', 'detained', 'death', 'coalition', 'close', 'can', 'call', 'along', 'Venezuela', 'Union', 'State', "Shi'ite", 'Russian', 'Pakistan', 'Nations', 'NATO', 'Last', 'July', 'India', 'French', 'France', 'Department', 'Authorities', '20', 'weeks', 'vote', 'virus', 'town', 'term', 'take', 'system', 'suspects', 'support', 'ruling', 'role', 'release', 'plans', 'newspaper', 'most', 'may', 'many', 'man', 'local', 'hit', 'him', 'help', 'head', 'ethnic', 'early', 'died', 'defense', 'days', 'crisis', 'court', 'confirmed', 'company', 'called', 'before', 'agreed', 'Washington', 'They', 'Security', 'Ministry', 'Germany', 'Ethiopia', 'Earlier', 'Cuba', 'Britain', 'Agency', '2008', '2003', 'working', 'wanted', 'visit', 'used', 'threat', 'should', 'she', 'seven', 'series', 'protests', 'place', 'party', 'part', 'outside', 'opposition', 'nearly', 'months', 'measures', 'main', 'long', 'left', 'hospital', 'further', 'free', 'force', 'face', 'expressed', 'constitution', 'clashes', 'car', 'bombings', 'board', 'army', 'agreement', 'administration', 'York', 'VOA', 'Strip', 'Somalia', 'Party', 'National', 'Muslim', 'May', 'Korean', 'Islamic', 'Hamas', 'Foreign', 'Beijing', '2007', 'well', 'weapons', 'third', 'terrorist', 'suicide', 'still', 'second', 'regional', 'price', 'opened', 'office', 'nation', 'ministry', 'met', 'market', 'major', 'kidnapped', 'food', 'family', 'eight', 'discuss', 'development', 'deal', 'deadly', 'companies', 'chief', 'change', 'case', 'carried', 'came' ...
# Test vocab size: 5078
# Sentence: I like learning new NLP models !
# Sentence vectorized: [1205 1023    1   71    1    1 5077]
# 'I' is in the vocabulary.
# 'like' is in the vocabulary.
# 'learning' is NOT in the vocabulary.
# 'new' is in the vocabulary.
# 'NLP' is NOT in the vocabulary.
# 'models' is NOT in the vocabulary.
# '!' is in the vocabulary.

# %%
print(Y_train[0:3])
# Out:
# [['B-geo', 'I-geo', 'O', 'O', 'B-tim', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'I-tim', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']]

# %%
def get_tags(tags):
    tag_set = set()
    for s in tags:
        for tag in s:
            tag_set.add(tag)
    tag_list = list(tag_set) 
    tag_list.sort()
    return tag_list

# %%
tags = get_tags(Y_train)
print(tags)
# Out:
# ['B-art', 'B-eve', 'B-geo', 'B-gpe', 'B-nat', 'B-org', 'B-per', 'B-tim', 'I-art', 'I-eve', 'I-geo', 'I-gpe', 'I-nat', 'I-org', 'I-per', 'I-tim', 'O']

# %%
def make_tag_map(tags):
    tag_map = {}
    for i,tag in enumerate(tags):
        tag_map[tag] = i 
    return tag_map

# %%
tag_map = make_tag_map(tags)
print(tag_map)
# Out:
# {'B-art': 0, 'B-eve': 1, 'B-geo': 2, 'B-gpe': 3, 'B-nat': 4, 'B-org': 5, 'B-per': 6, 'B-tim': 7, 'I-art': 8, 'I-eve': 9, 'I-geo': 10, 'I-gpe': 11, 'I-nat': 12, 'I-org': 13, 'I-per': 14, 'I-tim': 15, 'O': 16}
